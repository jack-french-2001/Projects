# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
from matplotlib.collections import PathCollection
import warnings
import numpy as np
from matplotlib.font_manager import findfont, FontProperties
warnings.filterwarnings('ignore')

# %%
# Set the font for the graphs
plt.rcParams["font.family"] = "serif"

# %% [markdown]
# #### Read in the csv files

# %%
adv_gk_22_23 = pd.read_csv("data/22_23.csv", encoding = "latin-1", sep = ";")
adv_gk_21_22 = pd.read_csv("data/21_22.csv", encoding = "latin-1", sep = ";")
adv_gk_20_21 = pd.read_csv("data/20_21.csv", encoding = "latin-1", sep = ";")
adv_gk_19_20 = pd.read_csv("data/19_20.csv", encoding = "latin-1", sep = ";")
adv_gk_18_19 = pd.read_csv("data/18_19.csv", encoding = "latin-1", sep = ";")
adv_gk_17_18 = pd.read_csv("data/17_18.csv", encoding = "latin-1", sep = ";")

basic_gk_22_23 = pd.read_csv("data/basic_22_23.csv", encoding = "latin-1", sep = ";")
basic_gk_21_22 = pd.read_csv("data/basic_21_22.csv", encoding = "latin-1", sep = ";")
basic_gk_20_21 = pd.read_csv("data/basic_20_21.csv", encoding = "latin-1", sep = ";")
basic_gk_19_20 = pd.read_csv("data/basic_19_20.csv", encoding = "latin-1", sep = ";")
basic_gk_18_19 = pd.read_csv("data/basic_18_19.csv", encoding = "latin-1", sep = ";")
basic_gk_17_18 = pd.read_csv("data/basic_17_18.csv", encoding = "latin-1", sep = ";")
basic_gk_16_17 = pd.read_csv("data/basic_16_17.csv", encoding = "latin-1", sep = ";")
basic_gk_15_16 = pd.read_csv("data/basic_15_16.csv", encoding = "latin-1", sep = ";")
basic_gk_14_15 = pd.read_csv("data/basic_14_15.csv", encoding = "latin-1", sep = ";")

passing_22_23 = pd.read_csv("data/passing_22_23.csv", encoding = "latin-1", sep = ";")
passing_21_22 = pd.read_csv("data/passing_21_22.csv", encoding = "latin-1", sep = ";")
passing_20_21 = pd.read_csv("data/passing_20_21.csv", encoding = "latin-1", sep = ";")
passing_19_20 = pd.read_csv("data/passing_19_20.csv", encoding = "latin-1", sep = ";")
passing_18_19 = pd.read_csv("data/passing_18_19.csv", encoding = "latin-1", sep = ";")
passing_17_18 = pd.read_csv("data/passing_17_18.csv", encoding = "latin-1", sep = ";")

# %% [markdown]
# #### Fix the column names

# %%
adv_gk_22_23.columns = adv_gk_22_23.iloc[1]
adv_gk_22_23 = adv_gk_22_23.iloc[2:]
adv_gk_22_23["Season"] = "2023-01-01"

adv_gk_21_22.columns = adv_gk_21_22.iloc[1]
adv_gk_21_22 = adv_gk_21_22.iloc[2:]
adv_gk_21_22["Season"] = "2022-01-01"

adv_gk_20_21.columns = adv_gk_20_21.iloc[1]
adv_gk_20_21 = adv_gk_20_21.iloc[2:]
adv_gk_20_21["Season"] = "2021-01-01"

adv_gk_19_20.columns = adv_gk_19_20.iloc[1]
adv_gk_19_20 = adv_gk_19_20.iloc[2:]
adv_gk_19_20["Season"] = "2020-01-01"

adv_gk_18_19.columns = adv_gk_18_19.iloc[1]
adv_gk_18_19 = adv_gk_18_19.iloc[2:]
adv_gk_18_19["Season"] = "2019-01-01"

adv_gk_17_18.columns = adv_gk_17_18.iloc[1]
adv_gk_17_18 = adv_gk_17_18.iloc[2:]
adv_gk_17_18["Season"] = "2018-01-01"

basic_gk_22_23.columns = basic_gk_22_23.iloc[1]
basic_gk_22_23 = basic_gk_22_23.iloc[2:]

basic_gk_21_22.columns = basic_gk_21_22.iloc[1]
basic_gk_21_22 = basic_gk_21_22.iloc[2:]

basic_gk_20_21.columns = basic_gk_20_21.iloc[1]
basic_gk_20_21 = basic_gk_20_21.iloc[2:]

basic_gk_19_20.columns = basic_gk_19_20.iloc[1]
basic_gk_19_20 = basic_gk_19_20.iloc[2:]

basic_gk_18_19.columns = basic_gk_18_19.iloc[1]
basic_gk_18_19 = basic_gk_18_19.iloc[2:]

basic_gk_17_18.columns = basic_gk_17_18.iloc[1]
basic_gk_17_18 = basic_gk_17_18.iloc[2:]

basic_gk_16_17.columns = basic_gk_16_17.iloc[0]
basic_gk_16_17 = basic_gk_16_17.iloc[2:]
basic_gk_16_17["Season"] = "2017-01-01"

basic_gk_15_16.columns = basic_gk_15_16.iloc[0]
basic_gk_15_16 = basic_gk_15_16.iloc[2:]
basic_gk_15_16["Season"] = "2016-01-01"

basic_gk_14_15.columns = basic_gk_14_15.iloc[0]
basic_gk_14_15 = basic_gk_14_15.iloc[2:]
basic_gk_14_15["Season"] = "2015-01-01"

passing_22_23.columns = passing_22_23.iloc[1]
passing_22_23 = passing_22_23.iloc[2:]
passing_22_23 = passing_22_23[passing_22_23[" Pos"] == "GK"]
passing_22_23["Season"] = "2023-01-01"

passing_21_22.columns = passing_21_22.iloc[1]
passing_21_22 = passing_21_22.iloc[2:]
passing_21_22 = passing_21_22[passing_21_22[" Pos"] == "GK"]
passing_21_22["Season"] = "2022-01-01"

passing_20_21.columns = passing_20_21.iloc[1]
passing_20_21 = passing_20_21.iloc[2:]
passing_20_21 = passing_20_21[passing_20_21[" Pos"] == "GK"]
passing_20_21["Season"] = "2021-01-01"

passing_19_20.columns = passing_19_20.iloc[1]
passing_19_20 = passing_19_20.iloc[2:]
passing_19_20 = passing_19_20[passing_19_20[" Pos"] == "GK"]
passing_19_20["Season"] = "2020-01-01"

passing_18_19.columns = passing_18_19.iloc[1]
passing_18_19 = passing_18_19.iloc[2:]
passing_18_19 = passing_18_19[passing_18_19[" Pos"] == "GK"]
passing_18_19["Season"] = "2019-01-01"

passing_17_18.columns = passing_17_18.iloc[1]
passing_17_18 = passing_17_18.iloc[2:]
passing_17_18 = passing_17_18[passing_17_18[" Pos"] == "GK"]
passing_17_18["Season"] = "2018-01-01"

# %% [markdown]
# #### Merge the advanced goalkeeping and basic goalkeeping data frames for the seasons 2017/18 to 2022/23

# %%
gk_22_23 = pd.merge(adv_gk_22_23, basic_gk_22_23, "left", on = " Player")
gk_21_22 = pd.merge(adv_gk_21_22, basic_gk_21_22, "left", on = " Player")
gk_20_21 = pd.merge(adv_gk_20_21, basic_gk_20_21, "left", on = " Player")
gk_19_20 = pd.merge(adv_gk_19_20, basic_gk_19_20, "left", on = " Player")
gk_18_19 = pd.merge(adv_gk_18_19, basic_gk_18_19, "left", on = " Player")
gk_17_18 = pd.merge(adv_gk_17_18, basic_gk_17_18, "left", on = " Player")

# %% [markdown]
# #### Concatenate all the merged goalkeeping dataframes together, concatenate all the passing dataframes together, concatenate the remaining basic goalkeeping dataframes

# %%
gk_all_years = pd.concat([gk_22_23, gk_21_22, gk_20_21, gk_19_20, gk_18_19, gk_17_18])
passing_all_years = pd.concat([passing_22_23, passing_21_22, passing_20_21, passing_19_20, passing_18_19, passing_17_18])
basic_gk = [basic_gk_16_17, basic_gk_15_16, basic_gk_14_15]
basic_gk_before_2018 = pd.concat(basic_gk)
basic_gk_before_2018.reset_index(inplace=True)
gk_all_years.reset_index(inplace = True)

# %% [markdown]
# #### Add a Season and Year column to all 3 dataframes

# %%
gk_all_years['Season'] = pd.to_datetime(gk_all_years['Season'], format = "%Y-%m-%d")
gk_all_years["Year"] = gk_all_years['Season'].dt.year

# %%
basic_gk_before_2018['Season'] = pd.to_datetime(basic_gk_before_2018['Season'], format = "%Y-%m-%d")
basic_gk_before_2018["Year"] = basic_gk_before_2018['Season'].dt.year

# %%
passing_all_years['Season'] = pd.to_datetime(passing_all_years['Season'], format = "%Y-%m-%d")
passing_all_years["Year"] = passing_all_years['Season'].dt.year

# %% [markdown]
# #### Add a column to indicate whether or not the datapoint is David de Gea

# %%
gk_all_years["isDeGea?"] = (gk_all_years[" Player"] == "David de Gea")
basic_gk_before_2018["isDeGea?"] = (basic_gk_before_2018[" Player"] == "David de Gea")
passing_all_years["isDeGea?"] = (passing_all_years[" Player"] == "David de Gea")

# %% [markdown]
# #### Add columns to the passing dataframe indicating the colour, alpha, and linewidth for David de Gea and for the other goalkeepers
# This is done for plotting purposes

# %%
colours = []
alpha = []
lw = []
for name in passing_all_years["isDeGea?"]:
    if name:
        colours.append("red")
        alpha.append(1)
        lw.append(3)
    else:
        colours.append("grey")
        alpha.append(0.5)
        lw.append(0.5)
passing_all_years["colour"] = colours
passing_all_years["alpha"] = alpha
passing_all_years["lw"] = lw

# %% [markdown]
# #### Pandas read in the numeric columns as strings so need to convert them to floats

# %%
for col in basic_gk_before_2018.columns[8:25]:
    basic_gk_before_2018[col] = basic_gk_before_2018[col].astype("float")

# %%
for col in passing_all_years.columns[8:32]:
    passing_all_years[col] = passing_all_years[col].astype("float")

# %%
for col in gk_all_years.columns[8:34]:
    gk_all_years[col] = gk_all_years[col].astype("float")
for col in gk_all_years.columns[49:63]:
    gk_all_years[col] = gk_all_years[col].astype("float")

# %% [markdown]
# #### Filter out players who have played less than 10 90s in all 3 dataframes

# %%
filtered_gk_all_years = gk_all_years[gk_all_years[" 90s_x"] > 10]
basic_gk_before_2018_filter = basic_gk_before_2018[basic_gk_before_2018[" 90s"] > 10]
passing_all_years_filter = passing_all_years[passing_all_years[" 90s"] > 10]

# %%
filtered_gk_all_years[filtered_gk_all_years["Performance Save%"] < 0.5]
# Out:
# 1    index  Rk_x         Player  Nation_x  Pos_x  Squad_x              Comp_x  \
# 526    117   115  Edouard Mendy    sn SEN     GK  Chelsea  eng Premier League
#
# 1    Age_x   Born_x   90s_x  ...  Performance CS%  Penalty Kicks PKatt  \
# 526     28   1992.0    30.5  ...              0.0                  0.0
#
# 1    Penalty Kicks PKA  Penalty Kicks PKsv  Penalty Kicks PKm  \
# 526                0.0                 0.0                0.0
#
# 1    Penalty Kicks Save%   Matches_y  #NAME?_y  Year  isDeGea?
# 526                  NaN     Matches  33887998  2021     False
#
# [1 rows x 68 columns]

# %%
filtered_gk_all_years[filtered_gk_all_years["Performance Save%"] == 100]
# Out:
# 1    index  Rk_x        Player  Nation_x  Pos_x   Squad_x         Comp_x  \
# 933     99    97  Gregor Kobel    ch SUI     GK  Augsburg  de Bundesliga
#
# 1    Age_x   Born_x   90s_x  ...  Performance CS%  Penalty Kicks PKatt  \
# 933     20   1997.0    15.4  ...              0.0                  1.0
#
# 1    Penalty Kicks PKA  Penalty Kicks PKsv  Penalty Kicks PKm  \
# 933                1.0                 0.0                0.0
#
# 1    Penalty Kicks Save%   Matches_y  #NAME?_y  Year  isDeGea?
# 933                  0.0     Matches  cd59b9df  2019     False
#
# [1 rows x 68 columns]

# %% [markdown]
# #### Remove any outliers

# %%
filtered_gk_all_years = filtered_gk_all_years[filtered_gk_all_years["Performance Save%"] > 0.5]
filtered_gk_all_years = filtered_gk_all_years[filtered_gk_all_years["Performance Save%"] < 100]

# %% [markdown]
# Function which splits a dataframe into smaller dataframes for each year

# %%
def split_years(dt):
    dt['year'] = dt['Season'].dt.year
    return [dt[dt['year'] == y] for y in dt['year'].unique()]

# %%
dfs = split_years(filtered_gk_all_years)
gk_22_23 = dfs[0]
gk_21_22 = dfs[1]
gk_20_21 = dfs[2]
gk_19_20 = dfs[3]
gk_18_19 = dfs[4]
gk_17_18 = dfs[5]

# %%
DDG_22_23 = gk_22_23[gk_22_23[" Player"] == "David de Gea"]
DDG_21_22 = gk_21_22[gk_21_22[" Player"] == "David de Gea"]
DDG_20_21 = gk_20_21[gk_20_21[" Player"] == "David de Gea"]
DDG_19_20 = gk_19_20[gk_19_20[" Player"] == "David de Gea"]
DDG_18_19 = gk_18_19[gk_18_19[" Player"] == "David de Gea"]
DDG_17_18 = gk_17_18[gk_17_18[" Player"] == "David de Gea"]
DDG_all_years = gk_all_years[gk_all_years[" Player"] == "David de Gea"]

# %%
save_perc = pd.DataFrame({"Year" : filtered_gk_all_years["Year"].append(basic_gk_before_2018_filter["Year"]), 
                        "Save%" : filtered_gk_all_years["Performance Save%"].append(basic_gk_before_2018_filter["Performance Save%"]), 
                        "isDeGea?" : filtered_gk_all_years["isDeGea?"].append(basic_gk_before_2018_filter["isDeGea?"])})

# %%
save_perc.reset_index(inplace = True)

# %%
DDG_save_perc = save_perc[save_perc["isDeGea?"] == True]

# %% [markdown]
# ### The swarmplot

# %%
fig, ax = plt.subplots(figsize = (15, 10))
ax1 = sns.scatterplot(x = DDG_save_perc["Year"].astype(str), y = DDG_save_perc["Save%"], 
                      ax = ax, color = "red", marker = "x", s = 100)
ax2 = sns.lineplot(x = DDG_save_perc["Year"].astype(str), y = DDG_save_perc["Save%"], 
                      ax = ax, color = "red")
plt.setp(ax.lines, zorder=100)
plt.setp(ax.collections, zorder=100, label="")
sns.swarmplot(data=save_perc, x="Year", y="Save%", ax = ax, color = "#C9C9C9", alpha = 0.75)
plt.gca().invert_xaxis()
ax.set_xticklabels(("2014/15", "2015/16", "2016/17", "2017/18", "2018/19", "2019/20", "2020/21", "2021/22", "2022/23")[::-1])
ax.set_ylabel("Save %", fontsize = 15)
ax.set_xlabel("", fontsize = 15)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.savefig('Save% edit.png', transparent=True)

# %%
not_DDG_passing = passing_all_years_filter[passing_all_years_filter["isDeGea?"] == False]
DDG_passing = passing_all_years_filter[passing_all_years_filter["isDeGea?"] == True]
not_DDG_passing.reset_index(inplace = True)
DDG_passing.reset_index(inplace = True)

# %%
dfs = split_years(not_DDG_passing)
not_DDG_passing_22_23 = dfs[0]
not_DDG_passing_21_22 = dfs[1]
not_DDG_passing_20_21 = dfs[2]
not_DDG_passing_19_20 = dfs[3]
not_DDG_passing_18_19 = dfs[4]
not_DDG_passing_17_18 = dfs[5]

dfs = split_years(DDG_passing)
DDG_passing_22_23 = dfs[0]
DDG_passing_21_22 = dfs[1]
DDG_passing_20_21 = dfs[2]
DDG_passing_19_20 = dfs[3]
DDG_passing_18_19 = dfs[4]
DDG_passing_17_18 = dfs[5]

dfs = split_years(passing_all_years_filter)
passing_22_23 = dfs[0]
passing_21_22 = dfs[1]
passing_20_21 = dfs[2]
passing_19_20 = dfs[3]
passing_18_19 = dfs[4]
passing_17_18 = dfs[5]

# %%
mean_total_att_per_year = passing_all_years_filter.groupby(['Season', "isDeGea?"]).mean()["Total Att"].reset_index()

# %%
dif_years = split_years(mean_total_att_per_year)

# %%
colours = ["#C9C9C9", "red"] 
for df in dif_years:
    df["colour"] = colours
    df.reset_index(inplace = True)

# %% [markdown]
# ### Small Multiple Barcharts

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 6, figsize = (17.5, 5))
for i in range(len(axs)):
    bars = axs[i].bar(x = dif_years[i]["isDeGea?"].astype(str), height = dif_years[i]["Total Att"], color = dif_years[i]["colour"])
    axs[i].set_ylim(0, 35)
    for j in range(2):
        if dif_years[i]["isDeGea?"][j]:
            continue
        else:
            bars[j].set_alpha(0.75)
    if i != 0:
        axs[i].spines['right'].set_visible(False)
        axs[i].spines['top'].set_visible(False)
        axs[i].spines['left'].set_visible(False)
        axs[i].set_ylabel("")
        axs[i].tick_params(right = False)
        axs[i].tick_params(right = False, left = False, labelleft = False)
    else:
        axs[i].spines['right'].set_visible(False)
        axs[i].spines['top'].set_visible(False)
        axs[i].set_ylabel("Total Attempted Passes per 90", fontsize = 15)
    axs[i].tick_params(
        axis='x', # changes apply to the x-axis
        which='both', # both major and minor ticks are affected
        bottom=False, # ticks along the bottom edge are off
        top=False, # ticks along the top edge are off
        labelbottom=False)
        
axs[0].set_title("2017/18", fontsize = 15)
axs[1].set_title("2018/19", fontsize = 15)
axs[2].set_title("2019/20", fontsize = 15)
axs[3].set_title("2020/21", fontsize = 15)
axs[4].set_title("2021/22", fontsize = 15)
axs[5].set_title("2022/23", fontsize = 15)

plt.savefig("Total Passes Attempted bar.png", transparent = True)

# %% [markdown]
# ### Small Multiple Scatterplots

# %%
alpha = 0.5
s = 125
gk_dfs = [gk_17_18, gk_18_19, gk_19_20, gk_20_21, gk_21_22, gk_22_23]
DDG_gk_dfs = [DDG_17_18, DDG_18_19, DDG_19_20, DDG_20_21, DDG_21_22, DDG_22_23]
fig, axs = plt.subplots(nrows = 1, ncols = 6, figsize = (17.5, 4.5))
for i in range(len(axs)):
    if i == 0:
        axs[i].scatter(gk_dfs[i]["Crosses Stp%"], gk_dfs[i]["Sweeper #OPA/90"], alpha = alpha, color = "#C9C9C9")
        axs[i].scatter(DDG_gk_dfs[i]["Crosses Stp%"], DDG_gk_dfs[i]["Sweeper #OPA/90"], color = "red", marker = "x", s = s)
        axs[i].set_ylabel("Offensive Actions Prevented per 90", fontsize = 15)
        axs[i].spines['right'].set_visible(False)
        axs[i].spines['top'].set_visible(False)
        axs[i].set_xlim(-0.5, 14)
        axs[i].set_ylim(0, 4)
    else:
        axs[i].scatter(gk_dfs[i]["Crosses Stp%"], gk_dfs[i]["Sweeper #OPA/90"], alpha = alpha, color = "#C9C9C9")
        axs[i].scatter(DDG_gk_dfs[i]["Crosses Stp%"], DDG_gk_dfs[i]["Sweeper #OPA/90"], color = "red", marker = "x", s = s)
        axs[i].set_ylabel("Offensive Actions Prevented per 90", fontsize = 15)
        axs[i].spines['right'].set_visible(False)
        axs[i].spines['top'].set_visible(False)
        axs[i].set_xlim(-0.5, 14)
        axs[i].set_ylim(0, 4)
        axs[i].spines['left'].set_visible(False)
        axs[i].set_ylabel("")
        axs[i].tick_params(right = False)
        axs[i].tick_params(right = False, left = False, labelleft = False)

axs[0].set_title("2017/18", fontsize = 15)
axs[1].set_title("2018/19", fontsize = 15)
axs[2].set_title("2019/20", fontsize = 15)
axs[3].set_title("2020/21", fontsize = 15)
axs[4].set_title("2021/22", fontsize = 15)
axs[5].set_title("2022/23", fontsize = 15)
plt.savefig("Proactviness.png", transparent = True)

# %% [markdown]
# ## UNUSED GRAPHS

# %%
f = filtered_gk_all_years[filtered_gk_all_years["isDeGea?"] == False]

palette = {
    False: '#C0C0C0',
    True: 'tab:red'
}
kwargs  =   {'edgecolor':"r", # for edge color
            }

fig, ax = plt.subplots(figsize = (9, 6))
ax1 = sns.scatterplot(x = DDG_all_years["Year"].astype(str), y = DDG_all_years["Expected PSxG+/-"], 
                      ax = ax, color = "red")
ax2 = sns.lineplot(x = DDG_all_years["Year"].astype(str), y = DDG_all_years["Expected PSxG+/-"], 
                      ax = ax, color = "red")
plt.setp(ax.lines, zorder=100)
plt.setp(ax.collections, zorder=100, label="")
sns.swarmplot(data=filtered_gk_all_years[filtered_gk_all_years["isDeGea?"] == False], x="Year", y="Expected PSxG+/-", ax = ax, color = "grey", alpha = 0.5)
plt.gca().invert_xaxis()

# %%
fig, ax = plt.subplots(figsize = (15, 7.5)) 
ax.vlines(passing_22_23_ordered[" Player"], ymin=0, ymax=passing_22_23_ordered["Total Att"], 
           color = passing_22_23_ordered["colour"], alpha = passing_22_23_ordered["alpha"], 
         lw =  passing_22_23_ordered["lw"])
ax.scatter(passing_22_23_ordered[" Player"], passing_22_23_ordered["Total Att"], 
            color = passing_22_23_ordered["colour"].values.tolist(), alpha = passing_22_23_ordered["alpha"])
ax.set_ylim(0, 60)
ax.set_xticks("")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set_ylabel("")
ax.tick_params(right = False)
ax.tick_params(right = False, left = False, labelleft = False)
ax.set_title("2022/23", fontsize = 25)

plt.savefig("Total Passes Attempted 2022_23.png", transparent = True)

# %%
passing_21_22_ordered.drop_duplicates(" Player", inplace = True)

# %%
fig, ax = plt.subplots(figsize = (15, 7.5)) 
ax.vlines(passing_21_22_ordered[" Player"], ymin=0, ymax=passing_21_22_ordered["Total Att"], 
           color = passing_21_22_ordered["colour"], alpha = passing_21_22_ordered["alpha"], 
          lw =  passing_21_22_ordered["lw"])
ax.scatter(passing_21_22_ordered[" Player"], passing_21_22_ordered["Total Att"], 
            color = passing_21_22_ordered["colour"].values.tolist(), alpha = passing_21_22_ordered["alpha"])
ax.set_ylim(0, 60)
ax.set_xticks("")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set_ylabel("")
ax.tick_params(right = False)
ax.tick_params(right = False, left = False, labelleft = False)
ax.set_title("2021/22", fontsize = 25)

plt.savefig("Total Passes Attempted 2021_22.png", transparent = True)

# %%
fig, ax = plt.subplots(figsize = (15, 7.5)) 
ax.vlines(passing_20_21_ordered[" Player"], ymin=0, ymax=passing_20_21_ordered["Total Att"], 
           color = passing_20_21_ordered["colour"], alpha = passing_20_21_ordered["alpha"], 
          lw =  passing_20_21_ordered["lw"])
ax.scatter(passing_20_21_ordered[" Player"], passing_20_21_ordered["Total Att"], 
            color = passing_20_21_ordered["colour"].values.tolist(), alpha = passing_20_21_ordered["alpha"])
ax.set_ylim(0, 60)
ax.set_xticks("")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_ylabel("")
ax.tick_params(right = False)
ax.tick_params(right = False)
ax.set_title("2020/21", fontsize = 25)
ax.set_ylabel("Total Attempted Passes per 90", fontsize = 20)
ax.set_yticklabels(ax.get_yticklabels(), fontsize = 15)

plt.savefig("Total Passes Attempted 2020_21.png", transparent = True)

# %%
fig, ax = plt.subplots(figsize = (15, 7.5)) 
ax.vlines(passing_19_20_ordered[" Player"], ymin=0, ymax=passing_19_20_ordered["Total Att"], 
           color = passing_19_20_ordered["colour"], alpha = passing_19_20_ordered["alpha"], 
          lw =  passing_19_20_ordered["lw"])
ax.scatter(passing_19_20_ordered[" Player"], passing_19_20_ordered["Total Att"], 
            color = passing_19_20_ordered["colour"].values.tolist(), alpha = passing_19_20_ordered["alpha"])
ax.set_ylim(0, 60)
ax.set_xticks("")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set_ylabel("")
ax.tick_params(right = False)
ax.tick_params(right = False, left = False, labelleft = False)
ax.set_title("2019/20", fontsize = 25)

plt.savefig("Total Passes Attempted 2019_20.png", transparent = True)

# %%
fig, ax = plt.subplots(figsize = (15, 7.5)) 
ax.vlines(passing_18_19_ordered[" Player"], ymin=0, ymax=passing_18_19_ordered["Total Att"], 
           color = passing_18_19_ordered["colour"], alpha = passing_18_19_ordered["alpha"], 
          lw =  passing_18_19_ordered["lw"])
ax.scatter(passing_18_19_ordered[" Player"], passing_18_19_ordered["Total Att"], 
            color = passing_18_19_ordered["colour"].values.tolist(), alpha = passing_18_19_ordered["alpha"])
ax.set_ylim(0, 60)
ax.set_xticks("")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set_ylabel("")
ax.tick_params(right = False)
ax.tick_params(right = False, left = False, labelleft = False)
ax.set_title("2018/19", fontsize = 25)
plt.savefig("Total Passes Attempted 2018_19.png", transparent = True)

# %%
fig, ax = plt.subplots(figsize = (15, 7.5)) 
ax.vlines(passing_17_18_ordered[" Player"], ymin=0, ymax=passing_17_18_ordered["Total Att"], 
           color = passing_17_18_ordered["colour"], alpha = passing_17_18_ordered["alpha"], 
          lw =  passing_17_18_ordered["lw"])
ax.scatter(passing_17_18_ordered[" Player"], passing_17_18_ordered["Total Att"], 
            color = passing_17_18_ordered["colour"].values.tolist(), alpha = passing_17_18_ordered["alpha"])
ax.set_ylim(0, 60)
ax.set_xticks("")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_ylabel("")
ax.tick_params(right = False)
ax.tick_params(right = False)
ax.set_ylabel("Total Attempted Passes per 90", fontsize = 20)
ax.set_yticklabels(ax.get_yticklabels(), fontsize = 15)
ax.set_title("2017/18", fontsize = 25)

plt.savefig("Total Passes Attempted 2017_18.png", transparent = True)

# %%
passing_dfs = [passing_17_18, passing_18_19, passing_19_20, passing_20_21, passing_21_22, passing_22_23]
fig, axs = plt.subplots(nrows = 1, ncols = 6, figsize = (17.5, 4.5))
for i in range(len(axs)):
    if i == 0:
        sns.distplot(passing_dfs[i]["Total Att"], hist = False, ax = axs[i], color = "grey", kde_kws={'alpha': 0.5})
        sns.rugplot(passing_dfs[i][passing_dfs[i]["isDeGea?"] == True]["Total Att"].values, color='red', height = 0.06,
           linewidth = 2, ax = axs[i])
        axs[i].set_xlim(15, 60)
        axs[i].set_ylim(0, 0.12)
        axs[i].spines['right'].set_visible(False)
        axs[i].spines['top'].set_visible(False)

    else:
        sns.distplot(passing_dfs[i]["Total Att"], hist = False, ax = axs[i], color = "grey", kde_kws={'alpha': 0.5})
        sns.rugplot(passing_dfs[i][passing_dfs[i]["isDeGea?"] == True]["Total Att"].values, color='red', height = 0.06,
           linewidth = 2, ax = axs[i])
        axs[i].set_xlim(15, 60)
        axs[i].set_ylim(0, 0.12)
        axs[i].spines['right'].set_visible(False)
        axs[i].spines['top'].set_visible(False)
        axs[i].spines['left'].set_visible(False)
        axs[i].set_ylabel("")
        axs[i].tick_params(right = False)
        axs[i].tick_params(right = False, left = False, labelleft = False)

axs[0].set_title("2017/18", fontsize = 15)
axs[1].set_title("2018/19", fontsize = 15)
axs[2].set_title("2019/20", fontsize = 15)
axs[3].set_title("2020/21", fontsize = 15)
axs[4].set_title("2021/22", fontsize = 15)
axs[5].set_title("2022/23", fontsize = 15)

ax1.set_xlabel("")
ax2.set_xlabel("")
ax3.set_xlabel("")
ax4.set_xlabel("")
ax5.set_xlabel("")
ax6.set_xlabel("")
# Out:
# Text(0.5, 4.444444444444445, '')

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(figsize = (17.5, 4), ncols = 6) 

sns.distplot(passing_22_23["Total Att"], hist = False, ax = ax6, color = "grey", kde_kws={'alpha': 0.5})
sns.rugplot(passing_22_23[passing_22_23["isDeGea?"] == True]["Total Att"].values, color='red', height = 0.06,
           linewidth = 2, ax = ax6)
ax6.set_xlim(15, 60)
ax6.set_ylim(0, 0.12)
ax6.spines['right'].set_visible(False)
ax6.spines['top'].set_visible(False)
ax6.spines['left'].set_visible(False)
ax6.set_ylabel("")
ax6.tick_params(right = False)
ax6.tick_params(right = False, left = False, labelleft = False)

sns.distplot(passing_21_22["Total Att"], hist = False, ax = ax5, color = "grey", kde_kws={'alpha': 0.5})
sns.rugplot(passing_21_22[passing_21_22["isDeGea?"] == True]["Total Att"].values, color='red', height = 0.06,
           linewidth = 2, ax = ax5)
ax5.set_xlim(15, 60)
ax5.set_ylim(0, 0.12)
ax5.spines['right'].set_visible(False)
ax5.spines['top'].set_visible(False)
ax5.spines['left'].set_visible(False)
ax5.set_ylabel("")
ax5.tick_params(right = False, left = False, labelleft = False)

sns.distplot(passing_20_21["Total Att"], hist = False, ax = ax4, color = "grey", kde_kws={'alpha': 0.5})
sns.rugplot(passing_20_21[passing_20_21["isDeGea?"] == True]["Total Att"].values, color='red', height = 0.06,
           linewidth = 2, ax = ax4)
ax4.set_xlim(15, 60)
ax4.set_ylim(0, 0.12)
ax4.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.set_ylabel("")
ax4.tick_params(right = False, left = False, labelleft = False)

sns.distplot(passing_19_20["Total Att"], hist = False, ax = ax3, color = "grey", kde_kws={'alpha': 0.5})
sns.rugplot(passing_19_20[passing_19_20["isDeGea?"] == True]["Total Att"].values, color='red', height = 0.06,
           linewidth = 2, ax = ax3)
ax3.set_xlim(15, 60)
ax3.set_ylim(0, 0.12)
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.set_ylabel("")
ax3.tick_params(right = False, left = False, labelleft = False)

sns.distplot(passing_18_19["Total Att"], hist = False, ax = ax2, color = "grey", kde_kws={'alpha': 0.5})
sns.rugplot(passing_18_19[passing_18_19["isDeGea?"] == True]["Total Att"].values, color='red', height = 0.06,
           linewidth = 2, ax = ax2)
ax2.set_xlim(15, 60)
ax2.set_ylim(0, 0.12)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.set_ylabel("")
ax2.tick_params(right = False, left = False, labelleft = False)

sns.distplot(passing_17_18["Total Att"], hist = False, ax = ax1, color = "grey", kde_kws={'alpha': 0.5})
sns.rugplot(passing_17_18[passing_17_18["isDeGea?"] == True]["Total Att"].values, color='red', height = 0.06,
           linewidth = 2, ax = ax1)
ax1.set_xlim(15, 60)
ax1.set_ylim(0, 0.12)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

ax1.set_title("2017/18")
ax2.set_title("2018/19")
ax3.set_title("2019/20")
ax4.set_title("2020/21")
ax5.set_title("2021/22")
ax6.set_title("2022/23")

ax1.set_xlabel("")
ax2.set_xlabel("")
ax3.set_xlabel("")
ax4.set_xlabel("")
ax5.set_xlabel("")
ax6.set_xlabel("")

# plt.savefig("Total Passes Attempted.png", transparent = True)
# Out:
# Text(0.5, 0, '')
